# %% [markdown]
# <a href="https://colab.research.google.com/github/snekumar/AD_Prediction/blob/main/2dCNN/sample_test_train2dcn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('project')
# Out:
# Mounted at project

# %%
# Importing TensorFlow and Keras modules
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import (
    BatchNormalization, Concatenate, Conv2D, Dense, Dropout, Flatten,
    GaussianNoise, GlobalAveragePooling2D, Input, MaxPooling2D, Rescaling,
    Resizing, SeparableConv2D)
import tensorflow.keras.layers as layers
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Importing data processing and visualization modules
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Importing scikit-learn modules
from sklearn.metrics import confusion_matrix

# Importing miscellaneous modules
import random
import time

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
len(gpus)
# Out:
# 1

# %%
batch_size = 32
img_height = 220
img_width = 220
seed = 69

# %%
train_data = tf.keras.utils.image_dataset_from_directory(
    "/content/project/MyDrive/project/Alzheimer_s Dataset/train",
    subset='training',
    validation_split=0.2,
    seed=seed,
    image_size=(img_height, img_width),
    batch_size=batch_size
)
# Out:
# Found 5125 files belonging to 4 classes.
# Using 4100 files for training.

# %%
val_data = tf.keras.utils.image_dataset_from_directory(
     "/content/project/MyDrive/project/Alzheimer_s Dataset/train",
    subset='validation',
    validation_split=0.2,
    seed=seed,
    image_size=(img_height, img_width),
    batch_size=batch_size
)
# Out:
# Found 5125 files belonging to 4 classes.
# Using 1025 files for validation.

# %%
class_names = train_data.class_names
num_classes = len(class_names)

print(f'{num_classes} classes: {class_names}')
# Out:
# 4 classes: ['AD', 'CN', 'MCI', 'NonDemented']

# %%
AUTOTUNE = tf.data.AUTOTUNEAUTOTUNE = tf.data.AUTOTUNE
train_data = train_data.cache().prefetch(buffer_size=AUTOTUNE)
val_data = val_data.cache().prefetch(buffer_size=AUTOTUNE)

# %%
def plot_images(n_rows=3, n_cols=7, data=val_data):
    plt.figure(figsize=(n_cols * 2, int(n_rows * 1.8)))
    for images, _ in data.take(int((n_rows * n_cols) / batch_size) + 1):  # "take" takes random batch
        for i in range(n_rows * n_cols):
            ax = plt.subplot(n_rows, n_cols, i + 1)
            plt.imshow(images[i].numpy().astype("uint16"))
            plt.axis("off")
plot_images()

# %%
import matplotlib.pyplot as plt

# Extract the class labels from the training data
class_labels = []
for _, labels in val_data:
    class_labels.extend(labels.numpy())

# Count the occurrences of each class label
class_counts = {}
for label in class_labels:
    if label in class_counts:
        class_counts[label] += 1
    else:
        class_counts[label] = 1

# Create a bar graph to visualize the class distribution
plt.figure(figsize=(10, 6))
plt.bar(class_counts.keys(), class_counts.values())
plt.xlabel("Class Label")
plt.ylabel("Count")
plt.title("Class Distribution in Testing Data")

# Add labels to the bars
for label, count in class_counts.items():
    plt.text(label, count, str(count), ha="center", va="bottom")

plt.show()

# %%
def plot_images(n_rows=3, n_cols=7, data=train_data):
    plt.figure(figsize=(n_cols * 2, int(n_rows * 1.8)))
    for images, _ in data.take(int((n_rows * n_cols) / batch_size) + 1):  # "take" takes random batch
        for i in range(n_rows * n_cols):
            ax = plt.subplot(n_rows, n_cols, i + 1)
            plt.imshow(images[i].numpy().astype("uint16"))
            plt.axis("off")

# %%
plot_images()

# %%
import matplotlib.pyplot as plt

# Extract the class labels from the training data
class_labels = []
for _, labels in train_data:
    class_labels.extend(labels.numpy())

# Count the occurrences of each class label
class_counts = {}
for label in class_labels:
    if label in class_counts:
        class_counts[label] += 1
    else:
        class_counts[label] = 1

# Create a bar graph to visualize the class distribution
plt.figure(figsize=(10, 6))
plt.bar(class_counts.keys(), class_counts.values())
plt.xlabel("Class Label")
plt.ylabel("Count")
plt.title("Class Distribution in Training Data")

# Add labels to the bars
for label, count in class_counts.items():
    plt.text(label, count, str(count), ha="center", va="bottom")

plt.show()

# %%
for image_batch, labels_batch in train_data:
    image_shape = image_batch.shape
    print(f"Image batch shape: {image_shape}")
    print(f"Label batch shape: {labels_batch.shape}")
    break
# Out:
# Image batch shape: (32, 220, 220, 3)
# Label batch shape: (32,)

# %% [markdown]
# # Model

# %%
normalization_layer = tf.keras.layers.Rescaling(scale=1./255)

# %%
input_layer = Input(shape=(img_width, img_height, 3))
gaussian_noise = GaussianNoise(0.15)(input_layer)

# %%
branch_1 = normalization_layer(gaussian_noise)

branch_1 = Conv2D(32, (3,3), padding='same', activation="relu")(branch_1)
branch_1 = BatchNormalization()(branch_1)
branch_1 = MaxPooling2D((2, 2))(branch_1)

branch_1 = Conv2D(64, (3,3), padding='same', activation="relu")(branch_1)
branch_1 = BatchNormalization()(branch_1)
branch_1 = MaxPooling2D((2, 2))(branch_1)

branch_1 = Conv2D(128, (3,3), padding='same', activation="relu")(branch_1)
branch_1 = BatchNormalization()(branch_1)
branch_1 = MaxPooling2D((2, 2))(branch_1)

branch_1 = Conv2D(64, (3,3), padding='same', activation="relu")(branch_1)
branch_1 = BatchNormalization()(branch_1)
branch_1 = MaxPooling2D((2, 2))(branch_1)

branch_1 = Flatten()(branch_1)

# %%
output_layers = Dense(256, activation='relu')(branch_1)
output_layers = Dense(128, activation='relu')(output_layers)

output_layers = Dropout(0.5)(output_layers)

output_layers = Dense(num_classes, activation='softmax')(output_layers)

# %% [markdown]
# model instance

# %%
model = tf.keras.Model(input_layer, output_layers)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
tf.keras.utils.plot_model(model, show_shapes=True, dpi=150)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 220, 220, 3)]     0
#
#  gaussian_noise (GaussianNoi  (None, 220, 220, 3)      0
#  se)
#
#  rescaling (Rescaling)       (None, 220, 220, 3)       0
#
#  conv2d (Conv2D)             (None, 220, 220, 32)      896
#
#  batch_normalization (BatchN  (None, 220, 220, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 110, 110, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 110, 110, 64)      18496
#
#  batch_normalization_1 (Batc  (None, 110, 110, 64)     256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 55, 55, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 55, 55, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 55, 55, 128)      512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 27, 27, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 27, 27, 64)        73792
#
#  batch_normalization_3 (Batc  (None, 27, 27, 64)       256
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 13, 13, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 10816)             0
#
#  dense (Dense)               (None, 256)               2769152
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_2 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 2,970,756
# Trainable params: 2,970,180
# Non-trainable params: 576
# _________________________________________________________________

# %% [markdown]
# 1. Early stopping

# %%
early_stopping= EarlyStopping(monitor='val_loss', patience=4,start_from_epoch=3,restore_best_weights=True)

# %% [markdown]
# 2. ReduceLROnPlateau

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, min_lr=1e-7)

# %% [markdown]
# Training

# %%
epochs = 40

history = model.fit(
  train_data,
  epochs = epochs,
  validation_data = val_data,
  batch_size = batch_size,
  callbacks = [early_stopping, reduce_lr],
  verbose = 1
)
# Out:
# Epoch 1/40
# 129/129 [==============================] - 9s 68ms/step - loss: 0.0084 - accuracy: 0.9993 - val_loss: 0.0589 - val_accuracy: 0.9785 - lr: 1.0000e-07
# Epoch 2/40
# 129/129 [==============================] - 9s 69ms/step - loss: 0.0084 - accuracy: 0.9990 - val_loss: 0.0590 - val_accuracy: 0.9785 - lr: 1.0000e-07
# Epoch 3/40
# 129/129 [==============================] - 10s 74ms/step - loss: 0.0080 - accuracy: 0.9990 - val_loss: 0.0590 - val_accuracy: 0.9785 - lr: 1.0000e-07
# Epoch 4/40
# 129/129 [==============================] - 9s 68ms/step - loss: 0.0062 - accuracy: 0.9995 - val_loss: 0.0591 - val_accuracy: 0.9785 - lr: 1.0000e-07
# Epoch 5/40
# 129/129 [==============================] - 9s 69ms/step - loss: 0.0083 - accuracy: 0.9993 - val_loss: 0.0591 - val_accuracy: 0.9785 - lr: 1.0000e-07
# Epoch 6/40
# 129/129 [==============================] - 10s 74ms/step - loss: 0.0092 - accuracy: 0.9990 - val_loss: 0.0590 - val_accuracy: 0.9785 - lr: 1.0000e-07
# Epoch 7/40
# 129/129 [==============================] - 9s 69ms/step - loss: 0.0085 - accuracy: 0.9988 - val_loss: 0.0589 - val_accuracy: 0.9785 - lr: 1.0000e-07
# Epoch 8/40
# 129/129 [==============================] - 9s 70ms/step - loss: 0.0077 - accuracy: 0.9993 - val_loss: 0.0589 - val_accuracy: 0.9785 - lr: 1.0000e-07
# Epoch 9/40
# 129/129 [==============================] - 10s 75ms/step - loss: 0.0084 - accuracy: 0.9993 - val_loss: 0.0589 - val_accuracy: 0.9785 - lr: 1.0000e-07
# Epoch 10/40
# 129/129 [==============================] - 9s 69ms/step - loss: 0.0080 - accuracy: 0.9990 - val_loss: 0.0588 - val_accuracy: 0.9785 - lr: 1.0000e-07
# Epoch 11/40
# 129/129 [==============================] - 9s 70ms/step - loss: 0.0071 - accuracy: 0.9993 - val_loss: 0.0588 - val_accuracy: 0.9785 - lr: 1.0000e-07
# Epoch 12/40
# 129/129 [==============================] - 9s 69ms/step - loss: 0.0083 - accuracy: 0.9983 - val_loss: 0.0587 - val_accuracy: 0.9785 - lr: 1.0000e-07
# Epoch 13/40
# 129/129 [==============================] - 9s 74ms/step - loss: 0.0093 - accuracy: 0.9988 - val_loss: 0.0587 - val_accuracy: 0.9785 - lr: 1.0000e-07
# Epoch 14/40
# 129/129 [==============================] - 9s 69ms/step - loss: 0.0080 - accuracy: 0.9995 - val_loss: 0.0588 - val_accuracy: 0.9785 - lr: 1.0000e-07
# Epoch 15/40
# 129/129 [==============================] - 9s 69ms/step - loss: 0.0080 - accuracy: 0.9990 - val_loss: 0.0587 - val_accuracy: 0.9785 - lr: 1.0000e-07
# Epoch 16/40
# 129/129 [==============================] - 10s 74ms/step - loss: 0.0090 - accuracy: 0.9993 - val_loss: 0.0586 - val_accuracy: 0.9785 - lr: 1.0000e-07
# Epoch 17/40
# 129/129 [==============================] - 9s 69ms/step - loss: 0.0062 - accuracy: 0.9995 - val_loss: 0.0586 - val_accuracy: 0.9785 - lr: 1.0000e-07
# Epoch 18/40
# 129/129 [==============================] - 9s 70ms/step - loss: 0.0087 - accuracy: 0.9988 - val_loss: 0.0586 - val_accuracy: 0.9785 - lr: 1.0000e-07
# Epoch 19/40
# 129/129 [==============================] - 10s 75ms/step - loss: 0.0079 - accuracy: 0.9993 - val_loss: 0.0586 - val_accuracy: 0.9785 - lr: 1.0000e-07
# Epoch 20/40
# 129/129 [==============================] - 9s 69ms/step - loss: 0.0084 - accuracy: 0.9990 - val_loss: 0.0585 - val_accuracy: 0.9795 - lr: 1.0000e-07
# Epoch 21/40
# 129/129 [==============================] - 9s 70ms/step - loss: 0.0073 - accuracy: 0.9988 - val_loss: 0.0585 - val_accuracy: 0.9795 - lr: 1.0000e-07
# Epoch 22/40
# 129/129 [==============================] - 9s 69ms/step - loss: 0.0078 - accuracy: 0.9990 - val_loss: 0.0586 - val_accuracy: 0.9795 - lr: 1.0000e-07
# Epoch 23/40
# 129/129 [==============================] - 9s 69ms/step - loss: 0.0083 - accuracy: 0.9993 - val_loss: 0.0585 - val_accuracy: 0.9795 - lr: 1.0000e-07
# Epoch 24/40
# 129/129 [==============================] - 9s 70ms/step - loss: 0.0073 - accuracy: 0.9993 - val_loss: 0.0585 - val_accuracy: 0.9795 - lr: 1.0000e-07
# Epoch 25/40
# 129/129 [==============================] - 10s 74ms/step - loss: 0.0080 - accuracy: 0.9988 - val_loss: 0.0585 - val_accuracy: 0.9795 - lr: 1.0000e-07
# Epoch 26/40
# 129/129 [==============================] - 9s 69ms/step - loss: 0.0093 - accuracy: 0.9985 - val_loss: 0.0584 - val_accuracy: 0.9795 - lr: 1.0000e-07
# Epoch 27/40
# 129/129 [==============================] - 9s 70ms/step - loss: 0.0078 - accuracy: 0.9995 - val_loss: 0.0585 - val_accuracy: 0.9795 - lr: 1.0000e-07
# Epoch 28/40
# 129/129 [==============================] - 9s 70ms/step - loss: 0.0085 - accuracy: 0.9995 - val_loss: 0.0583 - val_accuracy: 0.9795 - lr: 1.0000e-07
# Epoch 29/40
# 129/129 [==============================] - 9s 69ms/step - loss: 0.0070 - accuracy: 0.9993 - val_loss: 0.0583 - val_accuracy: 0.9795 - lr: 1.0000e-07
# Epoch 30/40
# 129/129 [==============================] - 9s 69ms/step - loss: 0.0083 - accuracy: 0.9995 - val_loss: 0.0583 - val_accuracy: 0.9795 - lr: 1.0000e-07
# Epoch 31/40
# 129/129 [==============================] - 10s 74ms/step - loss: 0.0077 - accuracy: 0.9993 - val_loss: 0.0582 - val_accuracy: 0.9795 - lr: 1.0000e-07
# Epoch 32/40
# 129/129 [==============================] - 9s 69ms/step - loss: 0.0072 - accuracy: 0.9993 - val_loss: 0.0582 - val_accuracy: 0.9795 - lr: 1.0000e-07
# Epoch 33/40
# 129/129 [==============================] - 9s 70ms/step - loss: 0.0084 - accuracy: 0.9990 - val_loss: 0.0581 - val_accuracy: 0.9795 - lr: 1.0000e-07
# Epoch 34/40
# 129/129 [==============================] - 9s 70ms/step - loss: 0.0071 - accuracy: 0.9998 - val_loss: 0.0581 - val_accuracy: 0.9795 - lr: 1.0000e-07
# Epoch 35/40
# 129/129 [==============================] - 9s 69ms/step - loss: 0.0066 - accuracy: 0.9998 - val_loss: 0.0580 - val_accuracy: 0.9795 - lr: 1.0000e-07
# Epoch 36/40
# 129/129 [==============================] - 9s 70ms/step - loss: 0.0096 - accuracy: 0.9983 - val_loss: 0.0580 - val_accuracy: 0.9795 - lr: 1.0000e-07
# Epoch 37/40
# 129/129 [==============================] - 9s 70ms/step - loss: 0.0085 - accuracy: 0.9985 - val_loss: 0.0580 - val_accuracy: 0.9795 - lr: 1.0000e-07
# Epoch 38/40
# 129/129 [==============================] - 10s 74ms/step - loss: 0.0080 - accuracy: 0.9993 - val_loss: 0.0579 - val_accuracy: 0.9795 - lr: 1.0000e-07
# Epoch 39/40
# 129/129 [==============================] - 9s 69ms/step - loss: 0.0076 - accuracy: 0.9993 - val_loss: 0.0580 - val_accuracy: 0.9795 - lr: 1.0000e-07
# Epoch 40/40
# 129/129 [==============================] - 9s 69ms/step - loss: 0.0073 - accuracy: 0.9993 - val_loss: 0.0581 - val_accuracy: 0.9795 - lr: 1.0000e-07

# %% [markdown]
# Model training and validation metrics

# %%
# Extract metrics from history object
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# Create figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 4))

# Plot accuracy metrics
ax1.plot(acc, label='Training Accuracy', color='blue', linestyle='solid')
ax1.plot(val_acc, label='Validation Accuracy', color='orange', linestyle='dashed')
ax1.set_xlabel('Epoch', fontsize=12)
ax1.set_ylabel('Accuracy', fontsize=12)
ax1.set_title('Training and Validation Accuracy', fontsize=10)
ax1.grid()

# Plot loss metrics
ax2.plot(loss, label='Training Loss', color='blue', linestyle='solid')
ax2.plot(val_loss, label='Validation Loss', color='orange', linestyle='dashed')
ax2.set_xlabel('Epoch', fontsize=12)
ax2.set_ylabel('Loss', fontsize=12)
ax2.set_title('Training and Validation Loss', fontsize=10)
ax2.grid()

# Add legend and title to figure
fig.legend(loc='lower center', ncol=2, fontsize=10)
fig.suptitle('Model Training History', fontsize=16)

# Show the plot

# %% [markdown]
# Validation
